# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
sns.set()
os.chdir('C:\\Users\\Administrator\\Documents\\Jupiter notebooks\\Python Assignments\\DataSets')

# %%
crime = pd.read_csv("kidnap_1.csv", encoding="Latin",dtype='object')
crime['K_A_Grand_Total'] = pd.to_numeric(crime['K_A_Grand_Total'])

# %%
#.1 .What is the major reason people being kidnapped in each state.
#df = crime.loc[:,['Area_Name','Group_Name','K_A_Grand_Total']]
#df = crime.groupby(['Area_Name','Group_Name']).max().K_A_Grand_Total

# %%
plt.figure(figsize=(28,9))
a=sns.barplot(x='Group_Name',y='K_A_Grand_Total',data=crime.sort_values('K_A_Grand_Total',ascending=False))
a

# %%
plt.figure(figsize=(28,11))
b=sns.barplot(x='Area_Name',y='K_A_Grand_Total',data=crime.sort_values('K_A_Grand_Total',ascending=False).head(15))
b

# %%
# From the 'a' plot we can see that kidnap for marriage is top reason for kidnap
# From the 'b' plot we can see Uttar Pradesh is the state where kidnap for marriage is maximum
